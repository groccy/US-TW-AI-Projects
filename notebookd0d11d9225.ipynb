# %% [markdown]
# # "DINO Self Supervised Vision Transformers"
# > Getting image embeddings with no negative samples
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Sachin Abeywardana
# - categories: [pytorch, pytorch lightning, loss function]
# - use_math: true
# - image: images/dino.png
# ![](https://i.imgur.com/4mdrr4x.png)
# Photo credit [Nicola Stocchi](https://www.flickr.com/photos/124313328@N08/26611532154)
#
# This implementation is based off of [this paper](https://arxiv.org/pdf/2104.14294.pdf) by FAIR. The reason I'm excited about this paper is because 1. I was able to implement this by reading the paper (don't underestimate how convoluted this step is) 2. We have a setting where we ignore any kind of labels altogether, i.e. completely self supervised.
#
# In a nutshell what the paper attempts to do, is to take two different augmentations of the same image, and try and push these embeddings closer together. Most (and possibly all) other such tasks attempt to do a triplet loss where the image is compared to a similar image (positive example), and different image(s) (negative examples). What's amazing about this paper is that it ignores negative examples altogether and is still able to get a meaningful embedding space for a given image.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Oct  2 00:10:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 511.65       Driver Version: 511.65       CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 6000    WDDM  | 00000000:B3:00.0 Off |                  Off |
# | 33%   29C    P8    16W / 260W |   3049MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1584    C+G                                   N/A      |
# |    0   N/A  N/A      1600    C+G                                   N/A      |
# |    0   N/A  N/A      6496    C+G                                   N/A      |
# |    0   N/A  N/A      7212    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A      7248    C+G   ...kyb3d8bbwe\Calculator.exe    N/A      |
# |    0   N/A  N/A     12092    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     12444    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     13296    C+G   ...8wekyb3d8bbwe\GameBar.exe    N/A      |
# |    0   N/A  N/A     13736    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     17908    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     18688    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A     18936    C+G   ...8wekyb3d8bbwe\Cortana.exe    N/A      |
# |    0   N/A  N/A     19716    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     20352    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     21508    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     22460    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     27976    C+G   ...e\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     29228    C+G                                   N/A      |
# |    0   N/A  N/A     31620    C+G   ...ekyb3d8bbwe\HxOutlook.exe    N/A      |
# |    0   N/A  N/A     34188    C+G   ...bbwe\HxCalendarAppImm.exe    N/A      |
# |    0   N/A  N/A     39268    C+G   ...y\ShellExperienceHost.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-gpu 2.3.0 requires numpy<1.19.0,>=1.16.0, but you have numpy 1.21.5 which is incompatible.
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
# Collecting typing-extensions>=4.0.0
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: torch>=1.9.* in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from pytorch_lightning) (1.10.2)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from pytorch_lightning) (6.0)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from pytorch_lightning) (21.3)
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from pytorch_lightning) (4.62.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.8.2-py3-none-any.whl (140 kB)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from pytorch_lightning) (1.21.5)
# Requirement already satisfied: requests in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.27.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.6.3)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.1)
# Requirement already satisfied: yarl<1.6.0,>=1.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.5.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.4.0)
# Requirement already satisfied: multidict<5.0,>=4.5 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (4.7.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from packaging>=17.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sandisk\appdata\roaming\python\python38\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (3.3.6)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\sandisk\appdata\roaming\python\python38\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (1.44.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\sandisk\appdata\roaming\python\python38\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (2.6.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (3.19.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (58.0.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sandisk\appdata\roaming\python\python38\site-packages (from tensorboard>=2.9.1->pytorch_lightning) (0.4.6)
# Requirement already satisfied: six in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from absl-py>=0.4->tensorboard>=2.9.1->pytorch_lightning) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch_lightning) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch_lightning) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning) (3.2.0)
# Requirement already satisfied: colorama in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tqdm>=4.57.0->pytorch_lightning) (0.4.4)
# Installing collected packages: typing-extensions, fsspec, torchmetrics, tensorboard, pyDeprecate, pytorch-lightning
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# Successfully installed fsspec-2022.8.2 pyDeprecate-0.3.2 pytorch-lightning-1.7.7 tensorboard-2.10.1 torchmetrics-0.9.3 typing-extensions-4.3.0

# %%
# hide
# !pip install deepspeed
#!pip install --upgrade wandb
import copy
from functools import partial
import multiprocessing as mp
from pathlib import Path
from typing import Any, Callable, List, Tuple
import random
import os
import shutil
import pathlib,PIL,glob
from torchvision import io, transforms

from deepspeed.ops.adam import FusedAdam
import matplotlib.pyplot as plt
import numpy as np
import pytorch_lightning as pl
#from pytorch_lightning.loggers import WandbLogger
from sklearn.model_selection import train_test_split
import torch
from torch.distributions.bernoulli import Bernoulli
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
# from torchvision.utils import Image, ImageDraw
from torchvision.transforms.functional import to_pil_image
from tqdm.auto import tqdm

# Wandb login:
# from kaggle_secrets import UserSecretsClient
#import wandb
# user_secrets = UserSecretsClient()
# secret_value = user_secrets.get_secret("wandb_api_key")
# wandb.login(key=secret_value)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %matplotlib inline
print(torch.__version__, pl.__version__)
# Out:
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_51a741ccb9584e989dad9c86d671a114\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_51a741ccb9584e989dad9c86d671a114\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-32r6k8s5'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_51a741ccb9584e989dad9c86d671a114\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_51a741ccb9584e989dad9c86d671a114\setup.py", line 151, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_51a741ccb9584e989dad9c86d671a114\setup.py", line 46, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3e/55/b96156249b18f640ff7d82f51159b68fd0cb158f3dc053d4c1449f02f24a/deepspeed-0.7.3.tar.gz#sha256=871399d1430022c31da3f3eac6ba603182b99feae6607c27b7a81a36c31e846d (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_066973cfa94241cbae247255edf770a4\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_066973cfa94241cbae247255edf770a4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-g4jukwqe'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_066973cfa94241cbae247255edf770a4\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_066973cfa94241cbae247255edf770a4\setup.py", line 151, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_066973cfa94241cbae247255edf770a4\setup.py", line 46, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2a/66/3cd92515f3167fb09f6b649e9cea0a571b0bf2997c6d1d377c987e953d57/deepspeed-0.7.2.tar.gz#sha256=862b2e5261ecd38fc8a110fd26b76bb223470fabac6a682af73bb54b5624c231 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_b0cf429f23e14565b6fe4c62d2ef78ed\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_b0cf429f23e14565b6fe4c62d2ef78ed\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-zjl18kwp'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_b0cf429f23e14565b6fe4c62d2ef78ed\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_b0cf429f23e14565b6fe4c62d2ef78ed\setup.py", line 151, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_b0cf429f23e14565b6fe4c62d2ef78ed\setup.py", line 46, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/96/29/8ca1e1f6a855459cbbb0c4a10f1d685d3b19535a8ad30d54d51b4739425a/deepspeed-0.7.1.tar.gz#sha256=630923825a38d10096e3eb53bafc62f7ec20b6b95e6dbdd4dc2eec26b1be42ae (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_6f6b31d1483a47789c5088cd4d31e955\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_6f6b31d1483a47789c5088cd4d31e955\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-wegsp7l6'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_6f6b31d1483a47789c5088cd4d31e955\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_6f6b31d1483a47789c5088cd4d31e955\setup.py", line 151, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_6f6b31d1483a47789c5088cd4d31e955\setup.py", line 46, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ea/07/1208b14565915291caab3557f3c6427701c08a06acab173ae830c68bd770/deepspeed-0.7.0.tar.gz#sha256=0ee39e1b01fe4ecbd89e7c4358db6327cee6fe52a201157999e1c995985453a4 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_f5aa28ea229d4376a474852edc9833e8\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_f5aa28ea229d4376a474852edc9833e8\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-4crzg2p2'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_f5aa28ea229d4376a474852edc9833e8\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_f5aa28ea229d4376a474852edc9833e8\setup.py", line 153, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_f5aa28ea229d4376a474852edc9833e8\setup.py", line 48, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3d/ab/f6f8c5972beead753aba767fb10c39d41de141bef71d4c783479158ec85c/deepspeed-0.6.7.tar.gz#sha256=85824e1901b02bf0ebf5902c17e2dad2377f50904a4927f59308f73230c162f4 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_a9c6d146e1a74a5ea864678b1733f894\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_a9c6d146e1a74a5ea864678b1733f894\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-rk9ioa4t'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_a9c6d146e1a74a5ea864678b1733f894\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_a9c6d146e1a74a5ea864678b1733f894\setup.py", line 153, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_a9c6d146e1a74a5ea864678b1733f894\setup.py", line 48, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ea/0b/0548359bf1d9484cdc0c250037acb7925eb6eb290f6ee20900eefbb551a0/deepspeed-0.6.6.tar.gz#sha256=14ffd0c5a9d20d6535fe650c15e0bdd1265890df7ae6dbbd202311c9caa7a47c (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_fa642ebd9f7a4176bb7b98187b7fa6c6\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_fa642ebd9f7a4176bb7b98187b7fa6c6\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-3cjpk_85'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_fa642ebd9f7a4176bb7b98187b7fa6c6\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_fa642ebd9f7a4176bb7b98187b7fa6c6\setup.py", line 152, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_fa642ebd9f7a4176bb7b98187b7fa6c6\setup.py", line 48, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/12/6c/35599340edea9a66552aec19490cc433822d4c86ccc8bc196090e301674f/deepspeed-0.6.5.tar.gz#sha256=97bf7b8966f264de38508057af28c768bccaba7aecd5778d5cf5f2bc97d36957 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_a05609bbd34a4abeb8e7e0de5a69fe6b\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_a05609bbd34a4abeb8e7e0de5a69fe6b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-v_ws63zd'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_a05609bbd34a4abeb8e7e0de5a69fe6b\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_a05609bbd34a4abeb8e7e0de5a69fe6b\setup.py", line 152, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_a05609bbd34a4abeb8e7e0de5a69fe6b\setup.py", line 48, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/d1/2380f40b7f3f72974130406ec0f758408fda491e156441f126c19f23f13d/deepspeed-0.6.4.tar.gz#sha256=ad2de46d6609798fa3525ef8eb0e1ddfb66e06983b0af967b462b1511f21cc9c (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_68dab9f935874bd3a8c4de61dfc5b8ce\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_68dab9f935874bd3a8c4de61dfc5b8ce\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-fa7ca15d'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_68dab9f935874bd3a8c4de61dfc5b8ce\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_68dab9f935874bd3a8c4de61dfc5b8ce\setup.py", line 152, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_68dab9f935874bd3a8c4de61dfc5b8ce\setup.py", line 48, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/50/e6/36e928da40cb2b5a978371ff245e220dcfc7ee963abdbd2acfc8f2717341/deepspeed-0.6.3.tar.gz#sha256=eb5ed5a12ad8a1388ad15358204f05d833ade1e9af0530e6e6aa613bead67a49 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_967b3b484c044e9dae402e2a280f32f1\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_967b3b484c044e9dae402e2a280f32f1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-0fi_4yks'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_967b3b484c044e9dae402e2a280f32f1\
#     Complete output (27 lines):
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     The system cannot find the file specified.
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_967b3b484c044e9dae402e2a280f32f1\setup.py", line 152, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_967b3b484c044e9dae402e2a280f32f1\setup.py", line 48, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile sparse_attn
#     DS_BUILD_OPS=1
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adam requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adam attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#      [WARNING]  cpu_adagrad requires the 'lscpu' command, but it does not exist!
#      [WARNING]  cpu_adagrad attempted to query 'lscpu' after failing to use py-cpuinfo to detect the CPU architecture. 'lscpu' does not appear to exist on your system, will fall back to use -march=native and non-vectorized execution.
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#     Installed CUDA version 11.6 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
#      [WARNING]  please install triton==1.0.0 if you want to use sparse attention
#      [WARNING]  One can disable sparse_attn with DS_BUILD_SPARSE_ATTN=0
#      [ERROR]  Unable to pre-compile sparse_attn
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4a/39/177c59ef1114e8518aa6f9880b67f656d2e73e91b3a23734de43c6a11f75/deepspeed-0.6.1.tar.gz#sha256=b3143b593f1b63c067aaaebd120e9d97915effbf4bf4f593840546cec2514ff1 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_584f2f8147334d618905ca4a1c86c3fd\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_584f2f8147334d618905ca4a1c86c3fd\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-ewk3fmpo'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_584f2f8147334d618905ca4a1c86c3fd\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_584f2f8147334d618905ca4a1c86c3fd\setup.py", line 167, in <module>
#         ext_modules.append(builder.builder())
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_584f2f8147334d618905ca4a1c86c3fd\op_builder\builder.py", line 592, in builder
#         assert_no_cuda_mismatch()
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_584f2f8147334d618905ca4a1c86c3fd\op_builder\builder.py", line 100, in assert_no_cuda_mismatch
#         raise Exception(
#     Exception: Installed CUDA version 11.6 does not match the version torch was compiled with 11.3, unable to compile cuda/cpp extensions without a matching cuda version.
#     DS_BUILD_OPS=1
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/53/8d/c4de44b359205f2203bde2a83769d3926b16d26fa87b89e027ead78b9e6a/deepspeed-0.6.0.tar.gz#sha256=98502df63dc53332cde601d644b29f2cf0234ea9d4d21c65b0d1d6db892e5fe1 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_58fc2858a8ac43cb98dc94598e4e468f\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_58fc2858a8ac43cb98dc94598e4e468f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-nvo6owrq'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_58fc2858a8ac43cb98dc94598e4e468f\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_58fc2858a8ac43cb98dc94598e4e468f\setup.py", line 149, in <module>
#         ext_modules.append(builder.builder())
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_58fc2858a8ac43cb98dc94598e4e468f\op_builder\builder.py", line 523, in builder
#         assert_no_cuda_mismatch()
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_58fc2858a8ac43cb98dc94598e4e468f\op_builder\builder.py", line 97, in assert_no_cuda_mismatch
#         raise Exception(
#     Exception: Installed CUDA version 11.6 does not match the version torch was compiled with 11.3, unable to compile cuda/cpp extensions without a matching cuda version.
#     DS_BUILD_OPS=1
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/8e/2c/c899ebb4b5c9b36d76f6bf527cee385869b3de23816b34ab9a2f6ab7afcc/deepspeed-0.5.10.tar.gz#sha256=871623ee95b2655595195b99a59f1eb3cf2eeb395fb3418d824eb62a350f7b83 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_44874144dd1143db94a3a54f02a41d24\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_44874144dd1143db94a3a54f02a41d24\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-kmwu5lhh'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_44874144dd1143db94a3a54f02a41d24\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_44874144dd1143db94a3a54f02a41d24\setup.py", line 138, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_44874144dd1143db94a3a54f02a41d24\setup.py", line 43, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile cpu_adam
#     DS_BUILD_OPS=1
#      [WARNING]  One can disable cpu_adam with DS_BUILD_CPU_ADAM=0
#      [ERROR]  Unable to pre-compile cpu_adam
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/12/ec/3839b145be0a5a5044355bedaf059e1aa00ae284a92a9510ddab70c4bdeb/deepspeed-0.5.9.tar.gz#sha256=7c43d151b51d346a430034e77764097c4af7637217c08503291c48c37ae7d090 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
# ...
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_bf08d9a3f0294185a02a340e507971e2\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_bf08d9a3f0294185a02a340e507971e2\setup.py", line 135, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_bf08d9a3f0294185a02a340e507971e2\setup.py", line 43, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile cpu_adam
#     DS_BUILD_OPS=1
#      [WARNING]  One can disable cpu_adam with DS_BUILD_CPU_ADAM=0
#      [ERROR]  Unable to pre-compile cpu_adam
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/b4/1823122b60a2d8c8120454d45edddb5d26bd548324b7d7f24b9e81d56fb8/deepspeed-0.4.5.tar.gz#sha256=72862cb6c1e00f199155046915129d801143e8fecc48e98f301a5f5aa32633fb (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_5052b250b7b244a59a34e7848c9981e1\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_5052b250b7b244a59a34e7848c9981e1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-hity11eh'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_5052b250b7b244a59a34e7848c9981e1\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_5052b250b7b244a59a34e7848c9981e1\setup.py", line 135, in <module>
#         abort(f"Unable to pre-compile {op_name}")
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_5052b250b7b244a59a34e7848c9981e1\setup.py", line 43, in abort
#         assert False, msg
#     AssertionError: Unable to pre-compile cpu_adam
#     DS_BUILD_OPS=1
#      [WARNING]  One can disable cpu_adam with DS_BUILD_CPU_ADAM=0
#      [ERROR]  Unable to pre-compile cpu_adam
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5f/6b/fe90f88b48d33489d3bd5aab98f56c01729feaa863e2b6a503fa95a733fa/deepspeed-0.4.4.tar.gz#sha256=1890bcd076e72321470556fbff30a46eaed0bf8ef69c7c6a39b0febf6fc598ee (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_78c6c84e5cbe4ef08b01b06c9a10b5cf\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_78c6c84e5cbe4ef08b01b06c9a10b5cf\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-gga7rbov'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_78c6c84e5cbe4ef08b01b06c9a10b5cf\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_78c6c84e5cbe4ef08b01b06c9a10b5cf\setup.py", line 124, in <module>
#         ext_modules.append(builder.builder())
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_78c6c84e5cbe4ef08b01b06c9a10b5cf\op_builder\builder.py", line 357, in builder
#         assert_no_cuda_mismatch()
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_78c6c84e5cbe4ef08b01b06c9a10b5cf\op_builder\builder.py", line 83, in assert_no_cuda_mismatch
#         raise Exception(
#     Exception: Installed CUDA version 11.6 does not match the version torch was compiled with 11.3, unable to compile cuda/cpp extensions without a matching cuda version.
#     DS_BUILD_OPS=1
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c5/f5/4c33e7f0af90e3f7a0719ef02167712914854f8cffe1bc2d4f82b20e213d/deepspeed-0.4.3.tar.gz#sha256=c1e4292d431a510d20694a40d8507d3386de79e842195410b92d2890a81131c4 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_87849327fc7146669ed149c458f866ba\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_87849327fc7146669ed149c458f866ba\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-c1da6qr3'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_87849327fc7146669ed149c458f866ba\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_87849327fc7146669ed149c458f866ba\setup.py", line 124, in <module>
#         ext_modules.append(builder.builder())
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_87849327fc7146669ed149c458f866ba\op_builder\builder.py", line 357, in builder
#         assert_no_cuda_mismatch()
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_87849327fc7146669ed149c458f866ba\op_builder\builder.py", line 83, in assert_no_cuda_mismatch
#         raise Exception(
#     Exception: Installed CUDA version 11.6 does not match the version torch was compiled with 11.3, unable to compile cuda/cpp extensions without a matching cuda version.
#     DS_BUILD_OPS=1
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/10/24/d43cf5f0ec0194671c3d6032bcb7ba381d2ce308d408f14378e3e5276390/deepspeed-0.4.2.tar.gz#sha256=6cd75cff921c0af9ef8521243b6ca7bd0e102880016379fdca0039c572fad638 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_e44e381655e24316b72ca9a78d95ce05\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_e44e381655e24316b72ca9a78d95ce05\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-32ar3ydg'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_e44e381655e24316b72ca9a78d95ce05\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_e44e381655e24316b72ca9a78d95ce05\setup.py", line 124, in <module>
#         ext_modules.append(builder.builder())
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_e44e381655e24316b72ca9a78d95ce05\op_builder\builder.py", line 357, in builder
#         assert_no_cuda_mismatch()
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_e44e381655e24316b72ca9a78d95ce05\op_builder\builder.py", line 83, in assert_no_cuda_mismatch
#         raise Exception(
#     Exception: Installed CUDA version 11.6 does not match the version torch was compiled with 11.3, unable to compile cuda/cpp extensions without a matching cuda version.
#     DS_BUILD_OPS=1
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/70/c8/9068af14c8d7792e0ca6aabae89c16ed2164c1dc2028f80e8cc201415158/deepspeed-0.4.1.tar.gz#sha256=4f402120d061160f7bfb4700b0d66f347df64e12e5144bad1f2628727a0bd9a1 (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Sandisk\.conda\envs\tf2d3-gpu\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_561f8b5805a849369b153003a516c817\\setup.py'"'"'; __file__='"'"'C:\\Users\\Sandisk\\AppData\\Local\\Temp\\pip-install-mojp4cxu\\deepspeed_561f8b5805a849369b153003a516c817\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Sandisk\AppData\Local\Temp\pip-pip-egg-info-r2886q0s'
#          cwd: C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_561f8b5805a849369b153003a516c817\
#     Complete output (10 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_561f8b5805a849369b153003a516c817\setup.py", line 113, in <module>
#         ext_modules.append(builder.builder())
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_561f8b5805a849369b153003a516c817\op_builder\builder.py", line 351, in builder
#         assert_no_cuda_mismatch()
#       File "C:\Users\Sandisk\AppData\Local\Temp\pip-install-mojp4cxu\deepspeed_561f8b5805a849369b153003a516c817\op_builder\builder.py", line 77, in assert_no_cuda_mismatch
#         raise Exception(
#     Exception: Installed CUDA version 11.6 does not match the version torch was compiled with 11.3, unable to compile cuda/cpp extensions without a matching cuda version.
#     DS_BUILD_OPS=1
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7e/67/eb2cc076dbd313a8716b4e9b8206cf04228117c95dcb19dc991514735fd5/deepspeed-0.4.0.tar.gz#sha256=a9b2f4d65bb0e81feecf280ba692de7f918fac4ee684ac1a8a232bb32824378a (from https://pypi.org/simple/deepspeed/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting deepspeed
#   Downloading deepspeed-0.7.3.tar.gz (717 kB)
#   Downloading deepspeed-0.7.2.tar.gz (704 kB)
#   Downloading deepspeed-0.7.1.tar.gz (704 kB)
#   Downloading deepspeed-0.7.0.tar.gz (629 kB)
#   Downloading deepspeed-0.6.7.tar.gz (586 kB)
#   Downloading deepspeed-0.6.6.tar.gz (578 kB)
#   Downloading deepspeed-0.6.5.tar.gz (567 kB)
#   Downloading deepspeed-0.6.4.tar.gz (556 kB)
#   Downloading deepspeed-0.6.3.tar.gz (554 kB)
#   Downloading deepspeed-0.6.1.tar.gz (541 kB)
#   Downloading deepspeed-0.6.0.tar.gz (548 kB)
#   Downloading deepspeed-0.5.10.tar.gz (515 kB)
#   Downloading deepspeed-0.5.9.tar.gz (510 kB)
#   Downloading deepspeed-0.5.8.tar.gz (517 kB)
#   Downloading deepspeed-0.5.7.tar.gz (519 kB)
#   Downloading deepspeed-0.5.6.tar.gz (490 kB)
#   Downloading deepspeed-0.5.5.tar.gz (488 kB)
#   Downloading deepspeed-0.5.4.tar.gz (483 kB)
#   Downloading deepspeed-0.5.3.tar.gz (477 kB)
#   Downloading deepspeed-0.5.2.tar.gz (477 kB)
#   Downloading deepspeed-0.5.1.tar.gz (476 kB)
#   Downloading deepspeed-0.5.0.tar.gz (475 kB)
#   Downloading deepspeed-0.4.5.tar.gz (457 kB)
#   Downloading deepspeed-0.4.4.tar.gz (457 kB)
#   Downloading deepspeed-0.4.3.tar.gz (451 kB)
#   Downloading deepspeed-0.4.2.tar.gz (448 kB)
#   Downloading deepspeed-0.4.1.tar.gz (445 kB)
#   Downloading deepspeed-0.4.0.tar.gz (444 kB)
#   Downloading deepspeed-0.3.16.tar.gz (385 kB)
# Requirement already satisfied: torch>=1.2 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from deepspeed) (1.10.2)
# Requirement already satisfied: torchvision>=0.4.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from deepspeed) (0.11.3)
# Requirement already satisfied: tqdm in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from deepspeed) (4.62.3)
# Collecting tensorboardX==1.8
#   Downloading tensorboardX-1.8-py2.py3-none-any.whl (216 kB)
# Collecting ninja
#   Downloading ninja-1.10.2.4-py2.py3-none-win_amd64.whl (293 kB)
# Requirement already satisfied: numpy in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from deepspeed) (1.21.5)
# Collecting psutil
#   Downloading psutil-5.9.2-cp38-cp38-win_amd64.whl (246 kB)
# Requirement already satisfied: protobuf>=3.2.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboardX==1.8->deepspeed) (3.19.4)
# Requirement already satisfied: six in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tensorboardX==1.8->deepspeed) (1.16.0)
# Requirement already satisfied: typing_extensions in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from torch>=1.2->deepspeed) (4.3.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from torchvision>=0.4.0->deepspeed) (8.4.0)
# Requirement already satisfied: colorama in c:\users\sandisk\.conda\envs\tf2d3-gpu\lib\site-packages (from tqdm->deepspeed) (0.4.4)
# Building wheels for collected packages: deepspeed
#   Building wheel for deepspeed (setup.py): started
#   Building wheel for deepspeed (setup.py): finished with status 'done'
#   Created wheel for deepspeed: filename=deepspeed-0.3.16-py3-none-any.whl size=394301 sha256=9f53f8f8d6730ae6c40cd8c3ebc7ff8d8612278ebac6fddf2fff75b1a70e2f56
#   Stored in directory: c:\users\sandisk\appdata\local\pip\cache\wheels\2b\9e\d2\69b941c1f3f94c0d79cd74d782e5cf4bf6ee93b6b3c660b5b2
# Successfully built deepspeed
# Installing collected packages: tensorboardX, psutil, ninja, deepspeed
# Successfully installed deepspeed-0.3.16 ninja-1.10.2.4 psutil-5.9.2 tensorboardX-1.8
# 1.10.2 1.7.7

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Image parameters
TRAIN_FILES = "/content/drive/MyDrive/DINO_WDC_test" #"/content/drive/MyDrive/NFT- TravelChubbies/Ian Images" #"../input/ben-molat/molat18/molat18/"
IMAGE_SIZE = 256
PATCH_SIZE = 16 #16
ZERO_PCT = 0.1
PATCHES_PER_ROW = (IMAGE_SIZE // PATCH_SIZE)
NUM_PATCHES = PATCHES_PER_ROW ** 2
RGB_CHANNELS = 4 #3
NUM_PIXELS = PATCH_SIZE ** 2 * RGB_CHANNELS
VALID_IMAGES = 5
TOPK = 18 #18 #20

# Training parameters
BATCH_SIZE = 16
EPOCHS = 10
LR = 1e-4

# Transformer parameters
N_HEADS = 8
N_LAYERS = 6

# Update constants
TEMPERATURE_S = 0.1
TEMPERATURE_T = 0.05
CENTER_MOMENTUM = 0.9
TEACHER_MOMENTUM = 0.995

# %% [markdown]
# ## Data
#
# The following shows how a given image is passed through two transforms (`RandomResizedCrop`) with one guaranteed to be atleast half as large as the original image. A collate function is then used to break it up into 16x16 patches so that we can fit it into a transformer. The collate function is a minor detail in the overall picture, but if you wish to read about it you can do so [here](https://sachinruk.github.io/blog/pytorch/data/2021/06/05/PyTorch-CollateFn.html).

# %%
class ImageData(Dataset):
    def __init__(self, files: List[str]):
        self.files = files
        self.randcrop_big = transforms.RandomResizedCrop((IMAGE_SIZE, IMAGE_SIZE), scale=(0.5, 1.0))
        self.randcrop_small = transforms.RandomResizedCrop((IMAGE_SIZE, IMAGE_SIZE))
        self.Center_Crop = transforms.CenterCrop(215) #### added
        
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, i):
        img = io.read_image(self.files[i])
        # img1 = self.randcrop_big(img)
        # img2 = self.randcrop_small(img)
        img1 = self.randcrop_big(self.Center_Crop(img)) #### added
        img2 = self.randcrop_small(self.Center_Crop(img)) ### added
        if img.shape[0] == 1:
            img1 = torch.cat([img1]*3)
            img2 = torch.cat([img2]*3)

        return img1, img2


class CollateFn:
    def reshape(self, batch):
        patches = torch.stack(batch)\
                    .unfold(2, PATCH_SIZE, PATCH_SIZE)\
                    .unfold(3, PATCH_SIZE, PATCH_SIZE)

        num_images = len(patches)
        patches = patches.reshape(
            num_images,
            RGB_CHANNELS, 
            NUM_PATCHES, 
            PATCH_SIZE, 
            PATCH_SIZE
        )
        patches.transpose_(1, 2)
        
        return patches.reshape(num_images, NUM_PATCHES, -1) / 255.0 - 0.5
        
    def __call__(
        self, batch: List[Tuple[torch.Tensor, torch.Tensor]]
    ) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        x1, x2 = zip(*batch)

        return self.reshape(x1), self.reshape(x2)

# %%
import pathlib,PIL,glob
data_dir = pathlib.Path(TRAIN_FILES)#'../input/ben-molat/molat18/molat18')
image_count = len(list(data_dir.glob('*.png'))) #len(list(data_dir.glob('*/*.jpg')))
print(image_count)
molat = list(data_dir.glob('*.png')) #list(data_dir.glob('*/*'))
orig_img = PIL.Image.open(str(molat[11]))
# Out:
# 247

# %%
torch.manual_seed(0)


def plot(imgs, with_orig=True, row_title=None, **imshow_kwargs):
    if not isinstance(imgs[0], list):
        # Make a 2d grid even if there's just 1 row
        imgs = [imgs]

    num_rows = len(imgs)
    num_cols = len(imgs[0]) + with_orig
    fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, squeeze=False)
    for row_idx, row in enumerate(imgs):
        row = [orig_img] + row if with_orig else row
        for col_idx, img in enumerate(row):
            ax = axs[row_idx, col_idx]
            ax.imshow(np.asarray(img), **imshow_kwargs)
            ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

    if with_orig:
        axs[0, 0].set(title='Original image')
        axs[0, 0].title.set_size(8)
    if row_title is not None:
        for row_idx in range(num_rows):
            axs[row_idx, 0].set(ylabel=row_title[row_idx])

    plt.tight_layout()

# %%
from torchvision import transforms as T
center_crops = [T.CenterCrop(size=size)(orig_img) for size in (100, 150, 215, orig_img.size)]
plot(center_crops)

# %% [markdown]
# Create a function to do image crop before training

# %%
# hide
class ImageOriginalData(Dataset):
    def __init__(self, files: List[str]):
        self.files = files
        self.resize = transforms.Resize((IMAGE_SIZE, IMAGE_SIZE))
        self.Center_Crop = transforms.CenterCrop(215) ### added center crop
        
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, i):
        img = io.read_image(self.files[i])
        if img.shape[0] == 1:
            img = torch.cat([img]*3)

        return self.resize(self.Center_Crop(img))  ### added center crop
    
class CollateSingleImage(CollateFn):    
    def __call__(
        self, batch: List[torch.Tensor]
    ) -> torch.FloatTensor:
        return self.reshape(batch)
    
# files = [str(file) for file in Path(TRAIN_FILES).glob("*.png")]
files = [str(file) for file in molat]
train_files, valid_files = train_test_split(files, test_size=0.15, random_state=42)
print(len(train_files),len(valid_files))
train_data = ImageData(train_files)
train_dl = DataLoader(
    train_data, 
    BATCH_SIZE, 
    shuffle=True, 
    drop_last=True, 
    num_workers=2, #4,
    pin_memory=True,
    collate_fn=CollateFn(),
)

valid_data = ImageOriginalData(valid_files)
valid_dl = DataLoader(
    valid_data, 
    BATCH_SIZE*2, 
    shuffle=False, 
    drop_last=False, 
    num_workers=2, #4,
    pin_memory=True,
    collate_fn=CollateSingleImage(),
)
# Out:
# 209 38

# %%
x, y = next(iter(train_dl))
x2 = next(iter(valid_dl))
(x.shape, y.shape), (x2.shape)
# Out:
# ((torch.Size([16, 256, 1024]), torch.Size([16, 256, 1024])),
#  torch.Size([32, 256, 1024]))

# %% [markdown]
# ## Model
# The model is simply the 256 image patches passed through an encoder transformer with a CLS token. However, a few things that I think newcomers to the transformer/ pytorch field ought to know is as follows (also I made these mistakes 😅).
# - Make sure to use `self.register_parameter` when declaring trainable variables in pytorch. doing `self.myvar = nn.Parameter(...)` is not enough.
# - I have used `LayerNorm` everywhere possible to keep gradient sizes reasonable for a optimizer with constant learning rate.
#
# The walkthough of the model operation ignoring normalisations is as follows:
# 1. Take the flattened 3x16x16 image patches and append them to a positional encoding.
# 2. Pass this through a linear layer and append the CLS token embedding to this.
# 3. Pass this through transformer, and take the 0th token since this correspond to the CLS token.
# 4. Normalize this vector to unit length so that you have a final image embedding.

# %%
class Model(nn.Module):
    def __init__(self, d_model, n_head, n_layers):
        super().__init__()
        # transformer
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=n_head)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)

        # positional embedding
        w_pos = torch.randn(NUM_PATCHES, d_model) / d_model ** 0.5
        cls_token = torch.randn(1, d_model) / d_model ** 0.5
        self.register_parameter("pos_embed", nn.Parameter(w_pos))
        self.register_parameter("cls_token", nn.Parameter(cls_token))

        # pixel projection
        self.linear = nn.Linear(2 * d_model, d_model)
        self.norm1 = nn.LayerNorm(2 * d_model, elementwise_affine=False)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        batch_size = len(x)
        position = torch.stack([self.pos_embed] * batch_size)
        x = torch.cat([x, position], dim=-1)
        pixel_proj = self.norm2(F.relu(self.linear(self.norm1(x))))
        batched_cls_token = torch.stack([self.cls_token]*batch_size)
        cls_x = torch.cat([batched_cls_token, pixel_proj], dim=1)
        
        cls_x.transpose_(0, 1)
        return F.normalize(self.encoder(cls_x)[0, ...], dim=-1)

# %% [markdown]
# ## Cross Entropy Loss, sort of
# We need a loss function that will push the output vector of the above model towards each other for the two augmented images. The way that this paper does it, is by treating the vector as a (log of) a histogram, and trying to line it up with its augmented version. Why is this interesting? Usually, most authors tend to simply take the dot product and maximise that to indicate that vectors need to line up (be close). This paper achieves the same result but by asking histograms to line up instead.
#
# The cross entropy loss takes on the form of $-\sum_{j=1}^J y_j\log p(x_j)$. This is minimised when $p(x_j)$ tends towards $y_j$. Similarly if we were to replace $y_j$ with a probability distribution $q_j\in[0, 1]\text{ s.t. }\sum_j q_j = 1$, p_j is minimised when the distributions line up.
#
# My personal intuition as to why this might be better might be as follows: (Feel free to correct me if I am wrong). When trying to maximise dot products, we are asking two points on a sphere to move towards each other. Now there is an obvious shortest path distance when you visualise it by drawing a line between the two points. However, going away from the point will also, eventually get you to the same point but by taking a longer time.
#
# By using the following equation we need two histograms to line up, which is a simpler derivative, and therefore more likely to get to a local minima faster.
# $$ \frac{1}{N}\sum_{n=1}^N\sum_{j=1}^J q_j\log p_j$$
#
# Note that in the implementation below, we have extra two concepts of centering, and using a temperature. I'm not sure about the centering, but the temperature variable (which is positive but less than one), sharpens the histogram, making the peaks more prominent.

# %%
class HLoss:
    def __init__(self, temperature_t: float, temperature_s: float):
        self.temperature_t = temperature_t
        self.temperature_s = temperature_s
        
    def __call__(
        self, 
        t: torch.FloatTensor, 
        s: torch.FloatTensor, 
        center: torch.FloatTensor
    ) -> torch.FloatTensor:
        t = F.softmax((t.detach() - center) / self.temperature_t, dim=1)
        log_s = F.log_softmax(s / self.temperature_s, dim=1)

        return -(t * log_s).sum(dim=1).mean()

# %% [markdown]
# ## Training
# The `LightningModule` below goes through the training step. The main steps are:
# 1. Create two copies of the model with the exact same parameters. One would be considered teacher (with the gradients not being calculated at backprop) and the student.
# 2. Pass both augmentations through both student and teacher.
# 3. Calculate the loss function shown above for the two augmentations, but with one embedding from teacher and the other from the student.
# 4. Calculate the new exponentially weighted teacher parameters with the corresponding student parameters.
# 5. Calculate a new (exponentially weighted) center parameter from the embeddings passed through the teacher only.
# Steps 1-4 being the most important aspects IMO. 5th step feels more like a trick needed to stabalize optimization.
#
# The following gif from the [official repo](https://github.com/facebookresearch/dino) is an overview of the algorithm:
# ![](https://github.com/facebookresearch/dino/raw/main/.github/dino.gif)

# %%
# hide
resize = transforms.Resize((IMAGE_SIZE, IMAGE_SIZE))
Center_Crop = transforms.CenterCrop(215)  ### added center crop

def get_closest(embedding: torch.FloatTensor, i: int):
    similarity = embedding @ embedding[i,:].T
    scores, idx = similarity.topk(TOPK)
    return scores.cpu().numpy(), idx.cpu().numpy()

def val_closest_pairs(embedding: torch.FloatTensor, i: int, files: List[str]):
    img = to_pil_image(resize(Center_Crop(io.read_image(files[i])))) ### added center crop
    closest_imgs = [img]
    scores, idx = get_closest(embedding, i)
    for i, score in zip(idx, scores):
        img = to_pil_image(resize(Center_Crop(io.read_image(files[i])))) ### added center crop
        closest_imgs.append(img)

    
# def get_closest_wandb_images(embedding: torch.FloatTensor, i: int, files: List[str]):
#     main_img = to_pil_image(resize(io.read_image(files[i])))
#     closest_imgs = [wandb.Image(main_img)]
    
#     scores, idx = get_closest(embedding, i)
    
#     for i, score in zip(idx, scores):
#         img = to_pil_image(resize(io.read_image(files[i])))
#         closest_imgs.append(
#             wandb.Image(img, caption=f"{score:.4f}")
#         )
        
#     return closest_imgs

# %%
class LightningModel(pl.LightningModule):
    def __init__(
        self,
        teacher: nn.Module,
        lr: float,
        loss_fn: Callable,
        valid_files: List[str],
        dim: int,
        center_momentum: float,
        param_momentum: float,
    ):
        super().__init__()
        self.teacher = teacher
        self.student = copy.deepcopy(teacher)
        self.lr = lr
        self.loss_fn = loss_fn
        self.c_mom = center_momentum
        self.p_mom = param_momentum
        self.register_buffer("center", torch.zeros((1, dim)).float())
        self.valid_files = valid_files
        
        for p in self.teacher.parameters():
            p.requires_grad = False

    def loss_calculation(
        self,
        batch: Tuple[torch.FloatTensor, torch.FloatTensor],
    ) -> torch.FloatTensor:
        x1, x2 = batch
        
        s1, s2 = self.student(x1), self.student(x2)
        t1, t2 = self.teacher(x1), self.teacher(x2)
        
        loss = self.loss_fn(t1, s2, self.center) + self.loss_fn(t2, s1, self.center)
        
        emperical_center = F.normalize(
            torch.cat([t1, t2]).mean(dim=0, keepdims=True),
            dim=-1,
        )
        return loss, emperical_center

    def training_step(
        self, batch: Tuple[torch.FloatTensor, torch.FloatTensor], *args: List[Any]
    ) -> torch.Tensor:
        loss, emperical_center = self.loss_calculation(batch)
        self.log(name="Training loss", value=loss, on_step=True, on_epoch=True)
        
        self.center = F.normalize(
            self.c_mom * self.center + (1 - self.c_mom) * emperical_center,
            dim=-1,
        )
        for s_p, t_p in zip(self.student.parameters(), self.teacher.parameters()):
            t_p.data = self.p_mom * t_p.data + (1 - self.p_mom) * s_p.data
        #print("loss -> ",loss)
        return loss
    
    def validation_step(self, images: torch.FloatTensor, *args: List[Any]) -> None:
        return self.teacher(images)
        
#     def validation_epoch_end(self, validation_step_outputs):
#         valid_embeds = torch.cat([pred for pred in validation_step_outputs])
#         columns = ["image"] + [f"closest_{i+1}" for i in range(TOPK)]
#         indices = np.random.choice(len(self.valid_files), VALID_IMAGES, replace=False)
#         rows = [val_closest_pairs(valid_embeds, i, self.valid_files) for i in indices]
#         table = wandb.Table(data=rows, columns=columns)
#         self.logger.experiment.log({f"epoch {self.current_epoch} results": table})
#         print(f"epoch {self.current_epoch} -> results": {table})
        
#     def on_after_backward(self):
#         if self.trainer.global_step % 50 == 0:  # don't make the tf file huge
#             global_step = self.trainer.global_step
#             for name, param in self.student.named_parameters():
#                 if "weight" in name and not "norm" in name and param.requires_grad:
#                     self.logger.experiment.log(
#                         {f"{name}_grad": wandb.Histogram(param.grad.cpu())}
#                     )

    def configure_optimizers(self) -> torch.optim.Optimizer:
        return FusedAdam(self.student.parameters(), lr=self.lr)

# %% [markdown]
# Thanks to PyTorch Lightning and WandB I can easily do half precision training and log the results to a beautiful dashboard, with results in the link below.

# %%
import torch
torch.cuda.empty_cache()

# %%
#!mkdir /kaggle/working/logs
teacher = Model(NUM_PIXELS, N_HEADS, N_LAYERS)
h_loss = HLoss(TEMPERATURE_T, TEMPERATURE_S)
lightning_model = LightningModel(
    teacher, 
    LR,
    h_loss,
    valid_files,
    NUM_PIXELS,
    CENTER_MOMENTUM, 
    TEACHER_MOMENTUM,
)

#logger = WandbLogger("DINO", "/kaggle/working/logs/", project="DINO")
trainer = pl.Trainer(
    max_epochs= 20, #EPOCHS,
    gpus=torch.cuda.device_count(),
    gradient_clip_val=1.0,
    #logger=logger,
    precision=16,
    limit_train_batches=10,
    num_sanity_val_steps=0,

)
trainer.fit(lightning_model, train_dl, valid_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:448: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   f"Setting `Trainer(gpus={gpus!r})` is deprecated in v1.7 and will be removed"
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit native Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Installed CUDA version 11.1 does not match the version torch was compiled with 11.3 but since the APIs are compatible, accepting this combination
# Using /root/.cache/torch_extensions/py37_cu113 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py37_cu113/fused_adam...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py37_cu113/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type  | Params
# ----------------------------------
# 0 | teacher | Model | 52.8 M
# 1 | student | Model | 52.8 M
# ----------------------------------
# 52.8 M    Trainable params
# 52.8 M    Non-trainable params
# 105 M     Total params
# 211.050   Total estimated model params size (MB)
# Loading extension module fused_adam...
# Time to load fused_adam op: 31.58548855781555 seconds
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1896: PossibleUserWarning: The number of training batches (10) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.

# %% [markdown]
# ## Evaluate results
# Finally lets look at some random images with its most closest images according to the model. Note that at this point, we throw away the student and simply take the teacher, even though it is only the student that used gradient information directly.

# %%
# hide
image_orig_data = ImageOriginalData(files)
image_orig_dl = DataLoader(
    image_orig_data, 
    BATCH_SIZE*2, 
    shuffle=False, 
    drop_last=False, 
    num_workers=4,
    pin_memory=True,
    collate_fn=CollateSingleImage(),
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
teacher = teacher.eval().to(device)
embedding = []
with torch.no_grad():
    for x in tqdm(image_orig_dl):
        out = teacher(x.to(device))
        embedding.append(out.cpu())
        
    embedding = torch.cat(embedding, dim=0)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
def plot_closest_pairs(embedding: torch.FloatTensor, i: int, files: List[str]):
    newpath = f'./sim_imgs_of_idx_{i}' 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    img = to_pil_image(resize(Center_Crop(io.read_image(files[i])))) ### added center crop
    plt.imshow(img)
    scores, idx = get_closest(embedding, i)
    
    fig, axs = plt.subplots(1, len(idx), figsize= (40,10)) #(12, 5))
    for i, score, ax in zip(idx, scores, axs):
        #print(i)
        destination = newpath
        source, image_name = os.path.split(files[i])
        shutil.copy(os.path.join(source, image_name), destination)
        img = to_pil_image(resize(Center_Crop(io.read_image(files[i]))))  ### added center crop
        ax.imshow(img)
        # ax.set_title(f"{score:.4f}")
        ax.set_title(f"{score:.8f}")

    plt.show()

# %%
io.read_image(files[1])
# Out:
# tensor([[[13, 13, 13,  ..., 28, 26, 24],
#          [14, 11, 11,  ..., 28, 26, 24],
#          [14, 11, 12,  ..., 26, 24, 21],
#          ...,
#          [ 2,  3,  2,  ...,  2,  2,  1],
#          [ 3,  3,  3,  ...,  2,  2,  1],
#          [ 3,  4,  4,  ...,  2,  3,  2]],
#
#         [[13, 13, 13,  ..., 23, 21, 19],
#          [14, 11, 11,  ..., 23, 21, 19],
#          [14, 11, 12,  ..., 21, 19, 16],
#          ...,
#          [ 2,  3,  2,  ...,  2,  2,  1],
#          [ 3,  3,  3,  ...,  2,  2,  1],
#          [ 3,  4,  4,  ...,  2,  3,  2]],
#
#         [[13, 13, 13,  ..., 19, 18, 16],
#          [14, 11, 11,  ..., 19, 18, 16],
#          [14, 11, 12,  ..., 18, 16, 13],
#          ...,
#          [ 4,  5,  4,  ...,  4,  4,  3],
#          [ 5,  5,  5,  ...,  4,  4,  3],
#          [ 5,  6,  6,  ...,  4,  5,  4]]], dtype=torch.uint8)

# %%
embedding[0].shape
# Out:
# torch.Size([1024])

# %%
i = 1 #64
plot_closest_pairs(embedding, i, files)

# %%
i = 11
plot_closest_pairs(embedding, i, files)

# %%
i = 21
plot_closest_pairs(embedding, i, files)

# %%
len(embedding)

# %%
# %%time
randn = random.sample(range(500, len(embedding)), 100)
for i in range(len(randn)):
    plot_closest_pairs(embedding, randn[i], files)
